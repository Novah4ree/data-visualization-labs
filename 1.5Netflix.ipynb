# %%
import pandas as pd

# %%
df = pd.read_csv("netflix_revenue_updated.csv")
df.head()
# Out:
#          Date  Global Revenue  UCAN Streaming Revenue  EMEA Streaming Revenue  \
# 0  31-03-2019      4520992000              2256851000              1233379000
# 1  30-06-2019      4923116000              2501199000              1319087000
# 2  30-09-2019      5244905000              2621250000              1428040000
# 3  31-12-2019      5467434000              2671908000              1562561000
# 4  31-03-2020      5767691000              2702776000              1723474000
#
#    LATM Streaming Revenue  APAC Streaming Revenue  UCAN Members  \
# 0               630472000               319602000      66633000
# 1               677136000               349494000      66501000
# 2               741434000               382304000      67114000
# 3               746392000               418121000      67662000
# 4               793453000               483660000      69969000
#
#    EMEA  Members  LATM Members  APAC Members  UCAN ARPU  EMEA ARPU  \
# ...

# %%
df.columns
# Out:
# Index(['Date', 'Global Revenue', 'UCAN Streaming Revenue',
#        'EMEA Streaming Revenue', 'LATM Streaming Revenue',
#        'APAC Streaming Revenue', 'UCAN Members', 'EMEA  Members',
#        'LATM Members', 'APAC Members', 'UCAN ARPU', 'EMEA ARPU', 'LATM  ARPU',
#        'APAC  ARPU', 'Netflix Streaming Memberships '],
#       dtype='object')

# %%
print("This dataset shows Netflix’s revenue and number of paid subscribers starting from 2012. The data comes from Netflix’s public financial reports and was shared on Kaggle. It includes information like the date, global revenue, and subscriber numbers in different regions such as the United States and Canada, Europe, Asia-Pacific, and Latin America. These features help show how Netflix has grown over time in both money and subscribers. This dataset is interesting to me because I’m a big movie fan and I use Netflix, so it’s cool to see how much the platform has grown over the years.")
# Out:
# This dataset shows Netflix’s revenue and number of paid subscribers starting from 2012. The data comes from Netflix’s public financial reports and was shared on Kaggle. It includes information like the date, global revenue, and subscriber numbers in different regions such as the United States and Canada, Europe, Asia-Pacific, and Latin America. These features help show how Netflix has grown over time in both money and subscribers. This dataset is interesting to me because I’m a big movie fan and I use Netflix, so it’s cool to see how much the platform has grown over the years.

# %%
print("The data came from Kaggle and is based on Netflix's public financial reports. the information was collected from reports that Netflix releases about its revenue and number of subscribers. These reports show how many users Netflix has and how much money it makes in different regions overtime.")
# Out:
# The data came from Kaggle and is based on Netflix's public financial reports. the information was collected from reports that Netflix releases about its revenue and number of subscribers. These reports show how many users Netflix has and how much money it makes in different regions overtime.

# %%
print("The features in this dataset are the date of the report, global Netflix revenue, and revenue from different regions such as the US and Canada, Europe, EMEA, Africa,Latin America and Asia. the dataset also includes the number of members in each region. Another feature shows total number of Netflix streaming memeberships worldwide. This dataset interest me because I am a huge movie fan and I personally use Netflix. It is interesting to see how many subscribers Netflix has and how much money the platform makes in different regions.")
# Out:
# The features in this dataset are the date of the report, global Netflix revenue, and revenue from different regions such as the US and Canada, Europe, EMEA, Africa,Latin America and Asia. the dataset also includes the number of members in each region. Another feature shows total number of Netflix streaming memeberships worldwide. This dataset interest me because I am a huge movie fan and I personally use Netflix. It is interesting to see how many subscribers Netflix has and how much money the platform makes in different regions.

# %%
print("Question-1:What is the maximum global revenue?")
# Out:
# Question-1:What is the maximum global revenue?

# %%
df["Global Revenue"].max
# Out:
# <bound method Series.max of 0     4520992000
# 1     4923116000
# 2     5244905000
# 3     5467434000
# 4     5767691000
# 5     6148286000
# 6     6435637000
# 7     6644442000
# 8     7163282000
# 9     7341777000
# 10    7483467000
# 11    7709318000
# 12    7867767000
# 13    7970141000
# 14    7925589000
# 15    7852053000
# 16    8161503000
# 17    8187301000
# 18    8541668000
# 19    8832825000
# 20    9370440000
# Name: Global Revenue, dtype: int64>

# %%
print("Question2: Can you show how the number of subscribers changed over time?")
# Out:
# Question2: Can you show how the number of subscribers changed over time?

# %%
df[['Date', 'LATM Members', 'APAC Members', 'UCAN ARPU', 'EMEA ARPU', 'LATM  ARPU',
       'APAC  ARPU']].head()
# Out:
#          Date  LATM Members  APAC Members  UCAN ARPU  EMEA ARPU  LATM  ARPU  \
# 0  31-03-2019      27547000      12141000      11.45      10.23        7.84
# 1  30-06-2019      27890000      12942000      12.52      10.13        8.14
# 2  30-09-2019      29380000      14485000      13.08      10.40        8.63
# 3  31-12-2019      31417000      16233000      13.22      10.51        8.18
# 4  31-03-2020      34318000      19835000      13.09      10.40        8.05
#
#    APAC  ARPU
# 0        9.37
# 1        9.29
# 2        9.29
# 3        9.07
# 4        8.94

# %%
print("Question3:What is the average global revenue for Netflix in the dataset?")
# Out:
# Question3:What is the average global revenue for Netflix in the dataset?

# %%
df["Global Revenue"].mean()
# Out:
# 7121887333.333333

# %%
print("Question4: Can you show a bar graph to show the different global revenue memberships?")
# Out:
# Question4: Can you show a bar graph to show the different global revenue memberships?

# %%
df['Global Revenue'].value_counts().plot(kind='bar', ylabel='Netflix Streaming Memberships', title='Netflix Revenue')
# Out:
# Matplotlib is building the font cache; this may take a moment.
# <Axes: title={'center': 'Netflix Revenue'}, xlabel='Global Revenue', ylabel='Netflix Streaming Memberships'>

# %%
print("Question5:Can you show how streamers grew over the time in Canada in a Graph.")
# Out:
# Question5:Can you show how streamers grew over the time in Canada in a Graph.

# %%
df['UCAN Streaming Revenue'].plot(kind='hist', ylabel=' Canada', title='Netflix Revenue')
# Out:
# <Axes: title={'center': 'Netflix Revenue'}, ylabel=' Canada'>
